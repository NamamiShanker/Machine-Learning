# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
columns = ['type', 'alchohol', 'malic_acid', 'ash', 'alcalinity', 'magnesium', 'phenols_total', 'flavanoids', 'phenols', 'proanthocyanins', 'intensity_color', 'hue', 'gib', 'proline']

len(columns)
# Out:
# 14

# %%
df = pd.read_csv('wine.data', names=columns)
df
# Out:
#      type  alchohol  malic_acid   ash  alcalinity  magnesium  phenols_total  \
# 0       1     14.23        1.71  2.43        15.6        127           2.80
# 1       1     13.20        1.78  2.14        11.2        100           2.65
# 2       1     13.16        2.36  2.67        18.6        101           2.80
# 3       1     14.37        1.95  2.50        16.8        113           3.85
# 4       1     13.24        2.59  2.87        21.0        118           2.80
# ..    ...       ...         ...   ...         ...        ...            ...
# 173     3     13.71        5.65  2.45        20.5         95           1.68
# 174     3     13.40        3.91  2.48        23.0        102           1.80
# 175     3     13.27        4.28  2.26        20.0        120           1.59
# 176     3     13.17        2.59  2.37        20.0        120           1.65
# 177     3     14.13        4.10  2.74        24.5         96           2.05
#
# ...

# %%
df.describe()
# Out:
#              type    alchohol  malic_acid         ash  alcalinity   magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#        phenols_total  flavanoids     phenols  proanthocyanins  \
# count     178.000000  178.000000  178.000000       178.000000
# mean        2.295112    2.029270    0.361854         1.590899
# std         0.625851    0.998859    0.124453         0.572359
# ...

# %%
mmscaler = MinMaxScaler()
mm = mmscaler.fit_transform(df)
mm
# Out:
# array([[0.        , 0.84210526, 0.1916996 , ..., 0.45528455, 0.97069597,
#         0.56134094],
#        [0.        , 0.57105263, 0.2055336 , ..., 0.46341463, 0.78021978,
#         0.55064194],
#        [0.        , 0.56052632, 0.3201581 , ..., 0.44715447, 0.6959707 ,
#         0.64693295],
#        ...,
#        [1.        , 0.58947368, 0.69960474, ..., 0.08943089, 0.10622711,
#         0.39728959],
#        [1.        , 0.56315789, 0.36561265, ..., 0.09756098, 0.12820513,
#         0.40085592],
#        [1.        , 0.81578947, 0.66403162, ..., 0.10569106, 0.12087912,
#         0.20114123]])

# %%
df_mm = pd.DataFrame(mm)
df_mm
# Out:
#        0         1         2         3         4         5         6  \
# 0    0.0  0.842105  0.191700  0.572193  0.257732  0.619565  0.627586
# 1    0.0  0.571053  0.205534  0.417112  0.030928  0.326087  0.575862
# 2    0.0  0.560526  0.320158  0.700535  0.412371  0.336957  0.627586
# 3    0.0  0.878947  0.239130  0.609626  0.319588  0.467391  0.989655
# 4    0.0  0.581579  0.365613  0.807487  0.536082  0.521739  0.627586
# ..   ...       ...       ...       ...       ...       ...       ...
# 173  1.0  0.705263  0.970356  0.582888  0.510309  0.271739  0.241379
# 174  1.0  0.623684  0.626482  0.598930  0.639175  0.347826  0.282759
# 175  1.0  0.589474  0.699605  0.481283  0.484536  0.543478  0.210345
# 176  1.0  0.563158  0.365613  0.540107  0.484536  0.543478  0.231034
# 177  1.0  0.815789  0.664032  0.737968  0.716495  0.282609  0.368966
#
#             7         8         9        10        11        12        13
# ...

# %%
sscaler = StandardScaler()
ss = sscaler.fit_transform(df)
ss
# Out:
# array([[-1.21394365,  1.51861254, -0.5622498 , ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [-1.21394365,  0.24628963, -0.49941338, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [-1.21394365,  0.19687903,  0.02123125, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 1.37386437,  0.33275817,  1.74474449, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 1.37386437,  0.20923168,  0.22769377, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.37386437,  1.39508604,  1.58316512, ..., -1.52437837,
#         -1.42894777, -0.59516041]])

# %%
df_ss = pd.DataFrame(ss)
df_ss
# Out:
#             0         1         2         3         4         5         6  \
# 0   -1.213944  1.518613 -0.562250  0.232053 -1.169593  1.913905  0.808997
# 1   -1.213944  0.246290 -0.499413 -0.827996 -2.490847  0.018145  0.568648
# 2   -1.213944  0.196879  0.021231  1.109334 -0.268738  0.088358  0.808997
# 3   -1.213944  1.691550 -0.346811  0.487926 -0.809251  0.930918  2.491446
# 4   -1.213944  0.295700  0.227694  1.840403  0.451946  1.281985  0.808997
# ..        ...       ...       ...       ...       ...       ...       ...
# 173  1.373864  0.876275  2.974543  0.305159  0.301803 -0.332922 -0.985614
# 174  1.373864  0.493343  1.412609  0.414820  1.052516  0.158572 -0.793334
# 175  1.373864  0.332758  1.744744 -0.389355  0.151661  1.422412 -1.129824
# 176  1.373864  0.209232  0.227694  0.012732  0.151661  1.422412 -1.033684
# 177  1.373864  1.395086  1.583165  1.365208  1.502943 -0.262708 -0.392751
#
#             7         8         9        10        11        12        13
# ...
